# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('USD_AMD Historical Data.csv')

# %%
dataset
# Out:
#            Date   Price    Open    High     Low  Vol. Change %
# 0    04/05/2024  387.47  388.59  392.50  388.23   NaN   -0.03%
# 1    04/04/2024  387.59  389.72  392.50  387.30   NaN   -0.29%
# 2    04/03/2024  388.72  390.99  392.50  387.86   NaN   -0.33%
# 3    04/02/2024  390.00  391.97  393.64  390.99   NaN   -0.25%
# 4    04/01/2024  390.97  393.28  394.64  391.48   NaN   -0.33%
# ..          ...     ...     ...     ...     ...   ...      ...
# 214  06/12/2023  385.40  386.18  387.20  385.59   NaN    0.36%
# 215  06/09/2023  384.00  387.00  387.50  384.50   NaN   -0.52%
# 216  06/08/2023  386.00  386.75  388.02  384.45   NaN    0.06%
# 217  06/07/2023  385.75  387.04  388.02  384.60   NaN   -0.08%
# 218  06/06/2023  386.04  387.28  388.14  384.60   NaN   -0.06%
#
# [219 rows x 7 columns]

# %%
plt.scatter(dataset["Date"], dataset["Price"], color = 'red')
plt.title('Changing AMD to USD')
plt.xlabel('Data')
plt.ylabel('AMD')
plt.show()
